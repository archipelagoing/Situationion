# %% [markdown]
# V7 — only if necessary
#
# You might not even need V7.
#
# If V6 produces a clean answer, you're basically at the point where you can integrate everything into the paper.
#
# So your project history becomes beautifully clean:
#
# V1 — DISCOVERY
#      ↓
# Found unusual mid-layer geometry
#
# V2 — INTERPRETATION
#      ↓
# Proposed situation-model explanation
#
# V3 — CONTROLLED DIAGNOSIS
#      ↓
# Counterfactuals
# Multiple readouts
# Attention diagnostic
# Lexical confound discovered
# Controlled effect discovered
# 23–26 hypothesis weakened
# New broad-emergence hypothesis
#
# V4 — LARGE-SCALE REPLICATION
#      ↓
# Strict structural controls
# 200–500 triples
# Held-out templates
# Statistics
# Dimension-specific geometry
# Test H1 vs H2
#
# V5 — DECODABILITY
#      ↓
# Layer-wise probes
# What situation information exists where?
# Attention relationship
# Projection controls
#
# V6 — CAUSALITY
#      ↓
# Activation patching
# Does GPT-2 actually USE the information?
#
# FINAL
#      ↓
# What is SituatiONION actually showing?
