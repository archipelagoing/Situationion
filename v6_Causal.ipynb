# %% [markdown]
# V6 — Causal Intervention
#
# Then activation patching gets its own notebook.
#
# Central question:
#
# Does GPT-2 actually use these representations to make predictions?
#
# V6:
#
# Select candidate layers based on V4/V5.
# Patch situation-preserving states.
# Patch situation-changing states.
# Compare early/middle/late layers.
# Random/noise controls.
# Lexical controls.
# Test causal specificity.
# Replicate across examples/templates/manipulations.
# Measure next-token probability changes.
#
# And importantly, don't decide your patching layers now. Let V4 and V5 determine them.
